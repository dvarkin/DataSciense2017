# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import time
import datetime
import pandas as pd
import os.path
from random import randint
# %matplotlib inline

# %%
def read_dump(path):
    return pd.read_csv(path, usecols=['ts'])

# %%
df = read_dump('news.csv')
df.reset_index(inplace=True)

sns.distplot(df.ts);

# df = df.groupby(pd.TimeGrouper(freq='1H'))
# df = df.agg({'title':'count'})
# df.reset_index(inplace=True)
# df = pd.melt(df, id_vars=["dt"],  var_name="title")
# df.groupby(["title", "dt"]).mean().unstack("title").plot()

plt.xlabel('dates')
plt.ylabel('news')
